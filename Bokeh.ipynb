# %%
from bokeh.plotting import figure, output_notebook, show

# prepare some data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [10**i for i in x]
y2 = [10**(i**2) for i in x]

# output to static HTML file
output_notebook()

# create a new plot
p = figure(
   tools="pan,box_zoom,reset,save",
   y_axis_type="log", y_range=[0.001, 10**11], title="log axis example",
   x_axis_label='sections', y_axis_label='particles'
)

# add some renderers
p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x", fill_color="white", size=8)
p.line(x, y0, legend="y=x^2", line_width=3)
p.line(x, y1, legend="y=10^x", line_color="red")
p.circle(x, y1, legend="y=10^x", fill_color="red", line_color="red", size=6)
p.line(x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="09e49748-bea2-49aa-952d-b009a59e27f7">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cf5f7c0b-ad92-4f72-8219-11ee8aeb152e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cf5f7c0b-ad92-4f72-8219-11ee8aeb152e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cf5f7c0b-ad92-4f72-8219-11ee8aeb152e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cf5f7c0b-ad92-4f72-8219-11ee8aeb152e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4b4cc1ae-39f6-4f80-b445-46c240905940":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.1,0.5,1.0,1.5,2.0,2.5,3.0],"y":[0.1,0.5,1.0,1.5,2.0,2.5,3.0]}},"id":"60690fd3-f424-4b04-9b30-4d518b22d063","type":"ColumnDataSource"},{"attributes":{"ticker":null},"id":"b3bdef53-0085-435d-8af9-5dd06c5217e1","type":"LogTickFormatter"},{"attributes":{"label":{"value":"y=x"},"renderers":[{"id":"7f40ea41-1b88-4394-9ade-92c806360896","type":"GlyphRenderer"},{"id":"224da31f-7841-4307-a876-b86411ab3a94","type":"GlyphRenderer"}]},"id":"3bef2f25-7b36-4b22-834e-1756f8c49d7f","type":"LegendItem"},{"attributes":{},"id":"7263c796-a84f-4b80-94ae-de1e02e36f48","type":"LinearScale"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ecaaa39a-88b5-4ccc-a31b-ba29f479c9d2","type":"Line"},{"attributes":{},"id":"fe44cd3a-da71-40ee-a408-09b811eef8a9","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.1,0.5,1.0,1.5,2.0,2.5,3.0],"y":[1.023292992280754,1.7782794100389228,10.0,177.82794100389228,10000.0,1778279.410038923,1000000000.0]}},"id":"00aa36f2-3ef3-479b-89b2-106aa124ad97","type":"ColumnDataSource"},{"attributes":{"num_minor_ticks":10},"id":"67987ab6-299f-4b65-80a0-c37603296393","type":"LogTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c25a96d3-7c00-4f86-84a6-4604a73ee80f","type":"PanTool"},{"id":"afa1f6fd-bbd9-4cdf-87a2-14193e0c524a","type":"BoxZoomTool"},{"id":"129f3611-85bc-4cc0-a2f1-124d64ebe1b0","type":"ResetTool"},{"id":"909e1b95-0bfd-4ba3-a641-d245ef94147f","type":"SaveTool"}]},"id":"22993d2b-bc66-4227-a630-4b1eadb2e37f","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6d8c7421-acf1-4d6e-8983-61a63defbd2f","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"white"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"2f3e9999-9c0b-44fe-8420-f4dd39380339","type":"Circle"},{"attributes":{"data_source":{"id":"2cd39680-8e65-4f0a-bb15-4148063470ef","type":"ColumnDataSource"},"glyph":{"id":"2b6a6010-954c-49bd-afd4-f92fa99439b8","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ecaaa39a-88b5-4ccc-a31b-ba29f479c9d2","type":"Line"},"selection_glyph":null},"id":"7f40ea41-1b88-4394-9ade-92c806360896","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2b6a6010-954c-49bd-afd4-f92fa99439b8","type":"Line"},{"attributes":{"data_source":{"id":"a096fd65-026d-4ad4-acfc-ca50d660bb26","type":"ColumnDataSource"},"glyph":{"id":"f44519d1-8e43-492d-8185-e81f0214d056","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"998b01e5-5bbd-4172-9854-26f31874dd85","type":"Line"},"selection_glyph":null},"id":"31b94d92-c14f-4fe5-a1df-3297b23e1922","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e92ca65-f126-481c-ac24-9c0830032854","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"8e3efeac-9748-4296-90eb-695b150aa8f5","type":"Circle"},{"attributes":{"data_source":{"id":"2d94afcf-3831-40b4-9fb3-9bcad3f5de81","type":"ColumnDataSource"},"glyph":{"id":"0e92ca65-f126-481c-ac24-9c0830032854","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1d95bfdb-1e59-4ee2-b3f7-9b27143ddd05","type":"Li ...

# %%
from bokeh.plotting import figure, output_notebook, show

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output to static HTML file
output_notebook()

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7143e91c-d144-4523-aa8e-a47b86c346a9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dde9fc2b-24b4-49dc-a0d9-0bbb7b69eba5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dde9fc2b-24b4-49dc-a0d9-0bbb7b69eba5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dde9fc2b-24b4-49dc-a0d9-0bbb7b69eba5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dde9fc2b-24b4-49dc-a0d9-0bbb7b69eba5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b9f1bda2-3b5c-4ef7-ba2d-4817351b372d":{"roots":{"references":[{"attributes":{"below":[{"id":"ca6c3cee-2918-4e50-8afe-60b98fd55aa1","type":"LinearAxis"}],"left":[{"id":"e01b09f3-f2a1-49c1-9d8d-b1a4519c2a3e","type":"LinearAxis"}],"renderers":[{"id":"ca6c3cee-2918-4e50-8afe-60b98fd55aa1","type":"LinearAxis"},{"id":"5c7edcad-2b29-46ce-beb6-e453d0a41548","type":"Grid"},{"id":"e01b09f3-f2a1-49c1-9d8d-b1a4519c2a3e","type":"LinearAxis"},{"id":"303b46da-4b64-43a7-943e-68b0ac6695d9","type":"Grid"},{"id":"0400601f-87e0-4d5d-a824-eb8ee98ebe0a","type":"BoxAnnotation"},{"id":"07179e6a-4e0e-452b-86df-b268e061b672","type":"Legend"},{"id":"787c0a17-f007-4f4b-afd3-147e6c9e2e2e","type":"GlyphRenderer"}],
},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dfd39c39-3da9-4dfc-bc0b-aee21e099acb","type":"PanTool"},{"id":"d03dd248-ec7a-4dc7-ab09-797287c9dc35","type":"WheelZoom ...

# %%
import numpy as np

from bokeh.plotting import figure, output_notebook, show

# prepare some data
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

# output to static HTML file (with CDN resources)
output_notebook()

TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))

# add a circle renderer with vectorized colors and sizes
p.circle(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a171b9fe-5f27-403b-8646-7843a0d280a0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9a623d7c-76f0-411d-af22-b145c948cc0f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9a623d7c-76f0-411d-af22-b145c948cc0f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9a623d7c-76f0-411d-af22-b145c948cc0f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9a623d7c-76f0-411d-af22-b145c948cc0f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"76bffb28-ac48-48cd-9fac-7bfa85f28a04":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"64ae3e54-3e80-44aa-a385-31389e338005","type":"ResizeTool"},{"id":"87d667e2-5156-4efd-99c2-7b76235773f2","type":"CrosshairTool"},{"id":"551ce19c-f8e5-4fdf-929c-660000dad0ac","type":"PanTool"},{"id":"fa6f4f57-acb8-43ad-b384-d542d99e384a","type":"WheelZoomTool"},{"id":"79101196-b5d9-4968-b4eb-6d98300404c6","type":"BoxZoomTool"},{"id":"bf6d1f2b-8b0a-4a1d-bc93-8cf90937b25c","type":"ResetTool"},{"id":"716a5756-073a-4d00-b0df-c63d2cbec9e9","type":"BoxSelectTool"},{"id":"88c9e10b-cac7-43e2-8f72-d6d97886ad4d","type":"LassoSelectTool"}]},"id":"02f64a22-4d2e-4460-a1c5-44a8ebd99275","type":"Toolbar"},{"attributes":{"plot":{"id":"2badd023-b63f-42af-b0e3-5ed3eac45386","subtype":"Figure","type":"Plot"}},"id":"551ce19c-f8e5-4fdf-929c-660000dad0ac","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"4121353c-862a-4b8a-9ce4-693672e64409","type":"PolyAnnotation"},{"attributes":{},"id":"f31dc36a-ce4e-4772-a681-fd9f19dc5a30","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","radius","fill_color"],"data":{"fill_color":["#6e9196","#4ed396","#39c096","#912996","#9cdb96","#f45d96","#db2696","#9ae496","#e7d796","#56d796","#7b9a96","#9b5596","#6d9696","#e4d296","#ea3a96","#489596","#6cc196","#ee6d96","#f29b96","#9de496","#982496","#ad8696","#abe196","#9d7b96","#a65896","#63c596","#c82296","#4b2496","#a3d896","#a8a496","#379796","#db5a96","#4b3e96","#96c496","#542f96","#542e96","#3b4e96","#35b696","#797b96","#f1b996","#598296","#c9d796","#4d3996","#96aa96","#f72896","#91b296","#627d96","#ad9096","#9e4196","#935296","#7fde96","#818996","#7b8f96","#e12496","#c9be96","#bdc196","#52a396","#3fa396","#48a496","#e4a596","#90c496","#b24196","#d8dc96","#6e7996","#b14996","#bcdd96","#6a3796","#796496","#4ada96","#d05c96","#cc3396","#a89f96","#687696","#ab4096","#763096","#b08b96","#3d9096","#a67096","#618f96","#766e96","#b86496","#8dc096","#e0d196","#ced296","#a2a196","#c57d96","#bc2f96","#f49b96","#59a496","#71d996","#e52a96","#6c2996","#e7e596","#608596","#673196","#9cbf96","#855296","#7fc496","#69c496","#c66b96","#b7d696","#4c5496","#c37396","#e6c596","#647596","#82e396","#708d96","#4b6f96","#779b96","#c08496","#db4496","#d37496","#895a96","#356796","#e45196","#b0ac96","#a3b196","#f1ba96","#c78896","#afb296","#be4396","#b3a396","#897d96","#5e6e96","#a83896","#905d96","#b68d96","#ece596","#cf5996","#f52696","#d05a96","#f8cb96","#a76596","#e78996","#e04f96","#a35096","#7a7996","#e52a96","#b87396","#5aba96","#6fd496","#6d8b96","#c4aa96","#649296","#c98e96","#ed6f96","#897196","#495196","#b5b796","#883596","#608596","#e2e396","#aad696","#3f7e96","#9eb896","#762e96","#de9896","#cf8696","#b22596","#83d696","#c68496","#a33196","#392996","#374b96","#436096","#dadd96","#79d896","#e52596","#c2ca96","#5b7f96","#86e496","#db5896","#938a96","#5b4d96","#513c96","#4dac96","#526b96","#5ae296","#927496","#a69f96","#db2496","#a2ce96","#9d7196","#43e396","#3e5d96","#89e496","#a39e96","#874996","#c9b996","#e93596","#ca5c96","#492096","#9e9296","#7a4896","#d36f96","#639e96","#3b3796","#f38096","#522b96","#562c96","#856196","#793496","#542096","#e08896","#b02596","#9cb996","#b43a96","#902796","#db7a96","#5f7f96","#755996","#983596","#b46296","#adb096","#792a96","#7e6b96","#b58996","#ea3a96","#e92996","#9a8696","#514f96","#8fb196","#33a596","#87a796","#5e8d96","#78bb96","#c02e96","#613d96","#cb6796","#b67396","#e98496","#8db896","#f04a96","#e4be96","#ca3496","#d37796","#e5ad96","#b3b896","#c65196","#e05096","#b46e96","#d05496","#f4be96","#624a96","#bf8f96","#dc7996","#816896","#369196","#4b6196","#ed8496","#bf3796","#bc9796"," ...

# %%
import numpy as np

from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_notebook, show

# prepare some data
N = 100
x = np.linspace(0, 4*np.pi, N)
y0 = np.sin(x)
y1 = np.cos(x)
y2 = np.sin(x) + np.cos(x)

# output to static HTML file
output_notebook()

# create a new plot
s1 = figure(width=250, plot_height=250, title=None)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# NEW: create a new plot and share both ranges
s2 = figure(width=250, height=250, x_range=s1.x_range, y_range=s1.y_range, title=None)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# NEW: create a new plot and share only one range
s3 = figure(width=250, height=250, x_range=s1.x_range, title=None)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# NEW: put the subplots in a gridplot
p = gridplot([[s1, s2, s3]], toolbar_location=None)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a861f6e8-da0d-4335-930d-8b59e63fb0cc">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e6ad502a-a2f6-494c-bd1b-e9963383857d","type":"Square"},"selection_glyph":null},"id":"912145a2-b8fa-42a3-833e-0af8a5f886e3","type":"GlyphRenderer"},{"attributes":{},"id":"00151772-c2b6-4da7-9cb1-389599e11a20","type":"BasicTickFormatter"},{"attributes":{},"id":"50eb95f3-74dd-4062-b7f0-e84dbc4a388c","type":"BasicTickFormatter"},{"attributes":{},"id":"314e4a30-dc2e-4f08-a431-852fc80c33a5","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"58e0a31a-481d-4478-9d71-82b0853027b0","subtype":"Figure","type":"Plot"}},"id":"9db81d72-e6f3-429c-bd49-542a70f78a00","type":"PanTool"},{"attributes":{"plot":{"id":"4d4c1e1f-4d4f-40b7-8cd8-7f7aed973047","subtype":"Figure","type":"Plot"}},"id":"6b6cdd14-3e69-4bf3-8fdf-51fe973d5766","type":"ResetTool"},{"attributes":{"overlay":{"id":"7b58222d-f36c-4142-8342-f93dce6f865f","type":"BoxAnnotation"},"plot":{"id":"58e0a31a-481d-4478-9d71-82b0853027b0","subtype":"Figure","type":"Plot"}},"id":"25dbb370-7733-4df9-ad77-b1ba7057f8be","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"1ac0eea5-bbf8-4149-8ef4-787727fb994b","type":"LinearAxis"}],"left":[{"id":"be97ba9e-e54a-4714-8e18-da7a8dc26cdc","type":"LinearAxis"}],"plot_height":250,"plot_width":250,"renderers":[{"id":"1ac0eea5-bbf8-4149-8ef4-787727fb994b","type":"LinearAxis"},{"id":"e2289899-e4ea-4c85 ...

# %%
import numpy as np

from bokeh.plotting import figure, output_notebook, show
from bokeh.sampledata.stocks import AAPL

# prepare some data
aapl = np.array(AAPL['adj_close'])
aapl_dates = np.array(AAPL['date'], dtype=np.datetime64)

window_size = 30
window = np.ones(window_size)/float(window_size)
aapl_avg = np.convolve(aapl, window, 'same')

# output to static HTML file
output_notebook()

# create a new plot with a a datetime axis type
p = figure(width=800, height=350, x_axis_type="datetime")

# add renderers
p.circle(aapl_dates, aapl, size=4, color='darkgrey', alpha=0.2, legend='close')
p.line(aapl_dates, aapl_avg, color='navy', legend='avg')

# NEW: customize by setting attributes
p.title.text = "AAPL One-Month Average"
p.legend.location = "top_left"
p.grid.grid_line_alpha=0
p.xaxis.axis_label = 'Date'
p.yaxis.axis_label = 'Price'
p.ygrid.band_fill_color="olive"
p.ygrid.band_fill_alpha = 0.1

# show the results
show(p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-f102e45f9af2> in <module>()
#       2
#       3 from bokeh.plotting import figure, output_notebook, show
# ----> 4 from bokeh.sampledata.stocks import AAPL
#       5
#       6 # prepare some data
#
# ~\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\bokeh\sampledata\stocks.py in <module>()
#      45     return data
#      46
# ---> 47 data_dir = _data_dir()
#      48
#      49 stocks = [
#
# ~\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\bokeh\sampledata\__init__.py in _data_dir(file_name, create)
#      36     if not exists(data_dir):
#      37         if not create:
# ---> 38             raise RuntimeError('bokeh sample data directory does not exist, please execute bokeh.sampledata.download()')
#      39         print("Creating %s directory" % data_dir)
#      40         try:
#
# RuntimeError: bokeh sample data directory does not exist, please execute bokeh.sampledata.download()
