# %%
from bokeh.plotting import figure, output_notebook, show

# prepare some data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [10**i for i in x]
y2 = [10**(i**2) for i in x]

# output to static HTML file
output_notebook()

# create a new plot
p = figure(
   tools="pan,box_zoom,reset,save",
   y_axis_type="log", y_range=[0.001, 10**11], title="log axis example",
   x_axis_label='sections', y_axis_label='particles'
)

# add some renderers
p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x", fill_color="white", size=8)
p.line(x, y0, legend="y=x^2", line_width=3)
p.line(x, y1, legend="y=10^x", line_color="red")
p.circle(x, y1, legend="y=10^x", fill_color="red", line_color="red", size=6)
p.line(x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4623013b-3be5-4f1b-85b4-5cf4c5b1c961">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="439a5653-c0f5-4fe6-bf71-5b3313c9636d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("439a5653-c0f5-4fe6-bf71-5b3313c9636d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("439a5653-c0f5-4fe6-bf71-5b3313c9636d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '439a5653-c0f5-4fe6-bf71-5b3313c9636d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"206c7764-aabb-4a70-8111-8eefc7f658ec":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d0016f95-f513-45e6-9e42-228c3e3e082d","type":"Line"},{"attributes":{"data_source":{"id":"d383e6f8-be5a-43e5-8266-5eea27e986ff","type":"ColumnDataSource"},"glyph":{"id":"cf338d8f-7ad1-4766-989f-8402f852318a","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d0016f95-f513-45e6-9e42-228c3e3e082d","type":"Line"},"selection_glyph":null},"id":"85f92e81-1902-46d1-8160-769dd2656853","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"5e157170-3b90-45fe-9711-4afda5eb0f8f","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb2f8ac5-2861-4b7d-b6f6-b80d2e5b0351","type":"LogTicker"}},"id":"fc48b5b7-a2d8-487a-b286-09fdd0a69a92","type":"Grid"},{"attributes":{"ticker":null},"id":"644c14aa-b4fe-4bf2-9bd1-3f1d0a787754","type":"LogTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"f3ee50fb-3e1f-40de-8ed8-16a45c140b06","type":"Line"},{"attributes":{"axis_label":"sections","formatter":{"id":"85184f33-8b13-49fb-be23-7c00dd53f22c","type":"BasicTickFormatter"},"plot":{"id":"5e157170-3b90-45fe-9711-4afda5eb0f8f","subtype":"Figure","type":"Plot"},"ticker":{"id":"ea7005a1-34b1-4473-a4d9-5d046d8237b2","type":"BasicTicker"}},"id":"df34a63a-59ec-42c3-8a06-750475f32a39","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6492ca75-1553-4e60-815a-a3e0c1348e44","type":"BoxAnnotation"},{"attributes":{},"id":"0f0a9446-ab0e-4bf2-86d1-58fa67596a48","type":"LinearScale"},{"attributes":{"axis_label":"particles","formatter":{"id":"644c14aa-b4fe-4bf2-9bd1-3f1d0a787754","type":"LogTickFormatter"},"plot":{"id":"5e157170-3b90-45fe-9711-4afda5eb0f8f","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb2f8ac5-2861-4b7d-b6f6-b80d2e5b0351","type":"LogTicker"}},"id":"58bed11b-ff63-4592-9f22-923908a45ec1","type":"LogAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.1,0.5,1.0,1.5,2.0,2.5,3.0],"y":[1.023292992280754,1.7782794100389228,10.0,177.82794100389228,10000.0,1778279.410038923,1000000000.0]}},"id":"5adf8c3e-fc6d-4c06-8073-69a8d240c2d5","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"7a865b31-8a57-4c84-9e3a-27176026a0c8","type":"Circle"},{"attributes":{"num_minor_ticks":10},"id":"eb2f8ac5-2861-4b7d-b6f6-b80d2e5b0351","type":"LogTicker"},{"attributes":{},"id":"85184f33-8b13-49fb-be23-7c00dd53f22c","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b35a5189-a61f-47b9-bf10-d7f89e4e2aab","type":"Line"},{"attributes":{"line_color":{"value":"orange"},"line_dash":[4,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"b02091e7-d668-460c-b94f-7d9bb5217871","type":"Line"},{"attributes":{"data_source":{"id":"ba81deb8-0de3-4256-8a85-27e7557207d7","type":"ColumnDataSource"},"glyph":{"id":"2fe98b41-a736-493e-84c7-d1d2dfd9ecf3","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"db000452-21d7-4a7c-9fa2-3370d511875a","type":"Circle"},"selection_glyph":null},"id":"14b3c1ce-adee-4d7c-b111-9063a7acd118","type":"GlyphRenderer"},{"attributes":{},"id":"ea7005a1-34b1-4473-a4d9-5d046d8237b2","type":"BasicTicker"},{"attributes":{"plot":{"id":"5e157170-3b90-45fe-9711-4afda5eb0f8f","subtype":"Figure","type":"Plot"}},"id ...

# %%
from bokeh.plotting import figure, output_notebook, show

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output to static HTML file
output_notebook()

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5e42abc8-2e71-4a60-9f49-c0320a900081">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="24e428cf-c778-478c-96cc-5ce9058fd896"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("24e428cf-c778-478c-96cc-5ce9058fd896");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("24e428cf-c778-478c-96cc-5ce9058fd896");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '24e428cf-c778-478c-96cc-5ce9058fd896' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"255f5933-b079-4bd9-9520-a1cc288b813a":{"roots":{"references":[{"attributes":{"label":{"value":"Temp."},"renderers":[{"id":"38b4f96e-ba29-40a1-b10f-2a6374701f4e","type":"GlyphRenderer"}]},"id":"cbb3878c-ae9b-45b5-9ac6-2a583d37049d","type":"LegendItem"},{"attributes":{"plot":{"id":"0d66c3ca-2ba7-4986-a07c-70230532a271","subtype":"Figure","type":"Plot"}},"id":"47247cf7-7763-46cb-8b56-6494cf9df4f0","type":"SaveTool"},{"attributes":{},"id":"fbba35c7-dad9-47e6-aac6-d9510ea0182a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0d66c3ca-2ba7-4986-a07c-70230532a271","subtype":"Figure","type":"Plot"},"ticker":{"id":"7f92e4c1-c518-4d29-a8d7-cc38122b6520","type":"BasicTicker"}},"id":"075c165a-f95f-4ba3-b7dd-aec8371cebb3","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":
},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"f47c4161-c0d1-4154-afc2-0f867f53e23c","type":"Line"},{"attributes":{},"id":"2b0ef8f3-7d94-485b-b698-e4ac31fd29a4","type":"LinearScale"},{"attributes":{"callback":null},"id":"da43fbda-6f99-4447-b420-8e7645b4f505","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"0d66c3ca-2ba7-4986-a07c-70230532a271","subtype":"Figure","type":"Plot"},"ticker":{"id":"65cd300b-e802-4cfa-a06d-764 ...

# %%
import numpy as np

from bokeh.plotting import figure, output_notebook, show

# prepare some data
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

# output to static HTML file (with CDN resources)
output_notebook()

TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))

# add a circle renderer with vectorized colors and sizes
p.circle(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cfc697f4-ee93-452d-bd4d-3259ca50cdbd">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9e8c325f-49e1-464c-bb86-b2e56276918a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9e8c325f-49e1-464c-bb86-b2e56276918a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9e8c325f-49e1-464c-bb86-b2e56276918a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9e8c325f-49e1-464c-bb86-b2e56276918a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"103a051d-4777-45d4-aa47-bb1719ea00df":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f5be999-cefd-4f62-be90-7ce045f8f980","type":"Circle"},{"attributes":{},"id":"35dfba73-3125-4d50-b284-c904a5ab94ba","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"23cc11a9-f12f-48f8-8417-1f1e06f3593d","subtype":"Figure","type":"Plot"}},"id":"7d0f4280-bfba-4e85-bff2-c5c9b48c2e87","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ad0327b8-1633-4cb2-b47a-95d11719ae93","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":""},"id":"27fc5856-5882-4387-826c-617a60d10805","type":"Title"},{"attributes":{"overlay":{"id":"c7a1c3d2-b863-432f-b624-706e14f265a6","type":"BoxAnnotation"},"plot":{"id":"23cc11a9-f12f-48f8-8417-1f1e06f3593d","subtype":"Figure","type":"Plot"}},"id":"67b2cc8c-6f98-4f17-a95b-38ff5a7b18c7","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":100},"id":"8a507970-5aa9-4ded-92c9-432c419e5210","type":"Range1d"},{"attributes":{"plot":{"id":"23cc11a9-f12f-48f8-8417-1f1e06f3593d","subtype":"Figure","type":"Plot"}},"id":"420fac39-5d2d-46f7-a31b-ddb0705588e5","type":"PanTool"},{"attributes":{"callback":null,"overlay":{"id":"6860a51f-1970-4af6-b1e3-3fe5ca411161","type":"PolyAnnotation"},"plot":{"id":"23cc11a9-f12f-48f8-8417-1f1e06f3593d","subtype":"Figure","type":"Plot"}},"id":"c3bc123f-70f8-4e2b-94eb-1721ab1cf864","type":"LassoSelectTool"},{"attributes":{"plot":{"id":"23cc11a9-f12f-48f8-8417-1f1e06f3593d","subtype":"Figure","type":"Plot"}},"id":"67b17b1e-d783-4a46-b512-58dc6fee3129","type":"ResetTool"},{"attributes":{},"id":"8e0f82e7-dd7d-4d7b-b59e-18c9ad0cb748","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["radius","x","y","fill_color"],"data":{"fill_color":["#985896","#6d7996","#d9b796","#ae6f96","#86c396","#aaa496","#ef9596","#d82396","#615496","#81ae96","#6d7696","#74a096","#e37596","#b32196","#f3b896","#48b496","#dd8996","#493196","#d2c896","#7da496","#f62b96","#a7e596","#3cda96","#6a9b96","#b05396","#37cd96","#6cbf96","#c9af96","#696196","#d02e96","#964196","#c27096","#f18796","#b8c296","#447196","#5d4e96","#ac4296","#8ec596","#62dc96","#a19e96","#a24c96","#a3d496","#d62b96","#785496","#323596","#98b496","#f18296","#b7d096","#b5a296","#b28896","#43a796","#dfbc96","#8f3d96","#86a796","#c64e96","#ef1f96","#339d96","#ea5096","#3e4896","#399d96","#88cc96","#f44996","#d81e96","#86cb96","#692696","#714c96","#689496","#9cda96","#de4196","#cf9e96","#8d5596","#722696","#669e96","#833696","#ef4596","#bf6296","#a07296","#e5d796","#bd5c96","#ba2996","#b65596","#842596","#38c096","#5ba996","#617c96","#dc5d96","#d22496","#6bad96","#b0cb96","#cf8196","#9c3696","#362796","#c29a96","#33c296","#e72396","#e0bb96","#4fa396","#a0ab96","#a27b96","#564e96","#682396","#868596","#764696","#5ecc96","#c14496","#c6a796","#6fb396","#a88596","#f56396","#817896","#665896","#383896","#3e5296","#57c396","#e26f96","#906496","#886f96","#c26596","#c78596","#598d96","#d5bd96","#e2b296","#b9d396","#dd9096","#77c896","#732f96","#87e596","#d0ac96","#917b96","#a1d396","#cb5196","#693396","#cc8996","#653496","#583796","#9d4f96","#9da496","#7eb596","#4a2196","#968c96","#6d3396","#efae96","#e05896","#871f96","#909296","#666996","#774596","#a5e496","#5b3396","#6d7296","#b57096","#e87896","#d5c696","#e9b696","#c95696","#e33396","#b84c96","#49a596","#d6c296","#3e7696","#d0da96","#656d96","#37b296","#d86196","#a15b96","#ebc796","#c65296","#f25096","#c45396","#796796","#c53196","#8abb96","#c7d896","#64ce96","#61b496","#5eb896 ...

# %%
import numpy as np

from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_notebook, show

# prepare some data
N = 100
x = np.linspace(0, 4*np.pi, N)
y0 = np.sin(x)
y1 = np.cos(x)
y2 = np.sin(x) + np.cos(x)

# output to static HTML file
output_notebook()

# create a new plot
s1 = figure(width=250, plot_height=250, title=None)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# NEW: create a new plot and share both ranges
s2 = figure(width=250, height=250, x_range=s1.x_range, y_range=s1.y_range, title=None)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# NEW: create a new plot and share only one range
s3 = figure(width=250, height=250, x_range=s1.x_range, title=None)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# NEW: put the subplots in a gridplot
p = gridplot([[s1, s2, s3]], toolbar_location=None)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="25b771f2-7a71-45dc-864f-12edc5bfcf94">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="aea0727e-2c94-4cc6-879a-3d8457a8e038"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("aea0727e-2c94-4cc6-879a-3d8457a8e038");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById
-6e683c517805","type":"LinearScale"},"y_range":{"id":"bc8a0d7b-b406-48da-bf2f-4898fbbd8354","type":"DataRange1d"},"y_scale":{"id":"2d4207f8-afdc-4b5c-ba4b-ead509c377ab","type":"LinearScale"}},"id":"cbaf8eea-6217-4c83-8699-811f48b98fe5","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"cbaf8eea-6217-4c83-8699-811f48b98fe5","subtype":"Figure","type":"Plot"},"ticker":{"id":"cdbe0993-0615-4a36-948d-c00963680e5d","type":"BasicTicker"}},"id":"a73cdaf3-93c0-4e7e-bccb-4ffdf4c97090","type":"Grid"},{"attributes":{"callback":null},"id":"98779904-cbe1-45a7-9322-33d027639ac3","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"f4dc7041-f06a-4536-b043-6bb665446323","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"cbaf8eea-6217-4c83-8699-811f48b98fe5","subtype":"Figure","type":"Plot"},"ticker":{"id":"7c31a018-e929-4930-81ce-08a49ea30b4d","type":"BasicTicker"}},"id":"fd4ce51d-7aa9-48d9-a51e-5e728a18470a","type":"Grid"},{"attributes":{},"id":"2d4207f8-afdc-4b5c-ba4b-ead509c377ab","type":"LinearScale"},{"attributes":{"overlay":{"id":"0e2fbee8-ccc6-464f-ba26-c2a796a99940","type":"BoxAnnotation"},"plot":{"id":"cbaf8eea-6217-4c83-8699-811f48b98fe5","subtype":"Figure","type":"Plot"}},"id":"c62f0adf-fe36-4876-ab26-8525f6a58d ...

# %%
import numpy as np

from bokeh.plotting import figure, output_notebook, show
from bokeh.sampledata.stocks import AAPL

# prepare some data
aapl = np.array(AAPL['adj_close'])
aapl_dates = np.array(AAPL['date'], dtype=np.datetime64)

window_size = 30
window = np.ones(window_size)/float(window_size)
aapl_avg = np.convolve(aapl, window, 'same')

# output to static HTML file
output_notebook()

# create a new plot with a a datetime axis type
p = figure(width=800, height=350, x_axis_type="datetime")

# add renderers
p.circle(aapl_dates, aapl, size=4, color='darkgrey', alpha=0.2, legend='close')
p.line(aapl_dates, aapl_avg, color='navy', legend='avg')

# NEW: customize by setting attributes
p.title.text = "AAPL One-Month Average"
p.legend.location = "top_left"
p.grid.grid_line_alpha=0
p.xaxis.axis_label = 'Date'
p.yaxis.axis_label = 'Price'
p.ygrid.band_fill_color="olive"
p.ygrid.band_fill_alpha = 0.1

# show the results
show(p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-f102e45f9af2> in <module>()
#       2
#       3 from bokeh.plotting import figure, output_notebook, show
# ----> 4 from bokeh.sampledata.stocks import AAPL
#       5
#       6 # prepare some data
#
# ~\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\bokeh\sampledata\stocks.py in <module>()
#      45     return data
#      46
# ---> 47 data_dir = _data_dir()
#      48
#      49 stocks = [
#
# ~\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\bokeh\sampledata\__init__.py in _data_dir(file_name, create)
#      36     if not exists(data_dir):
#      37         if not create:
# ---> 38             raise RuntimeError('bokeh sample data directory does not exist, please execute bokeh.sampledata.download()')
#      39         print("Creating %s directory" % data_dir)
#      40         try:
#
# RuntimeError: bokeh sample data directory does not exist, please execute bokeh.sampledata.download()
